# %% [markdown]
# # Cas pratique sur la base de données diamonds
# ### Import de la base de données
# La base de données diamonds, que vous connaissez déjà pour avoir travaillé dessus notamment avec R, fait partie des bases que databricks met à disposition directement sur son système de gestion de données (DBFS).  Vous la trouverez au format csv en suivant ce chemin : `/databricks-datasets/Rdatasets/data-001/csv/ggplot2`.
# - Affichez les bases qui se trouvent dans ce même chemin avec la fonction `dbutils.fs.ls`.
# - Importez la base `diamonds` en utilisant `spark.read` et affichez les 10 premières lignes.
# - utilisez la fonction `printSchema()` pour affichez les variables de la base et leurs types. Si les types ne correspondent pas, revenez à votre import et spécifiez la valeur du paramètre `inferSchema`.

# %%
# le dossier en question contient les tables au format csv présentes dans la librairie ggplot2 de R : 
dbutils.fs.ls("/databricks-datasets/Rdatasets/data-001/csv/ggplot2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[102]: [FileInfo(path=&#39;dbfs:/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv&#39;, name=&#39;diamonds.csv&#39;, size=3192560),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/Rdatasets/data-001/csv/ggplot2/economics.csv&#39;, name=&#39;economics.csv&#39;, size=20731),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/Rdatasets/data-001/csv/ggplot2/midwest.csv&#39;, name=&#39;midwest.csv&#39;, size=100539),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/Rdatasets/data-001/csv/ggplot2/movies.csv&#39;, name=&#39;movies.csv&#39;, size=6000709),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/Rdatasets/data-001/csv/ggplot2/mpg.csv&#39;, name=&#39;mpg.csv&#39;, size=17345),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/Rdatasets/data-001/csv/ggplot2/msleep.csv&#39;, name=&#39;msleep.csv&#39;, size=7182),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/Rdatasets/data-001/csv/ggplot2/presidential.csv&#39;, name=&#39;presidential.csv&#39;, size=512),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/Rdatasets/data-001/csv/ggplot2/seals.csv&#39;, name=&#39;seals.csv&#39;, size=64016)]</div>

# %%
# On importe la table et on affiche les 10 premières lignes avec display : 
diamonds = spark.read.csv("/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv", header="true", inferSchema = "true")
display(diamonds.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>carat</th><th>cut</th><th>color</th><th>clarity</th><th>depth</th><th>table</th><th>price</th><th>x</th><th>y</th><th>z</th></tr></thead><tbody><tr><td>1</td><td>0.23</td><td>Ideal</td><td>E</td><td>SI2</td><td>61.5</td><td>55.0</td><td>326</td><td>3.95</td><td>3.98</td><td>2.43</td></tr><tr><td>2</td><td>0.21</td><td>Premium</td><td>E</td><td>SI1</td><td>59.8</td><td>61.0</td><td>326</td><td>3.89</td><td>3.84</td><td>2.31</td></tr><tr><td>3</td><td>0.23</td><td>Good</td><td>E</td><td>VS1</td><td>56.9</td><td>65.0</td><td>327</td><td>4.05</td><td>4.07</td><td>2.31</td></tr><tr><td>4</td><td>0.29</td><td>Premium</td><td>I</td><td>VS2</td><td>62.4</td><td>58.0</td><td>334</td><td>4.2</td><td>4.23</td><td>2.63</td></tr><tr><td>5</td><td>0.31</td><td>Good</td><td>J</td><td>SI2</td><td>63.3</td><td>58.0</td><td>335</td><td>4.34</td><td>4.35</td><td>2.75</td></tr><tr><td>6</td><td>0.24</td><td>Very Good</td><td>J</td><td>VVS2</td><td>62.8</td><td>57.0</td><td>336</td><td>3.94</td><td>3.96</td><td>2.48</td></tr><tr><td>7</td><td>0.24</td><td>Very Good</td><td>I</td><td>VVS1</td><td>62.3</td><td>57.0</td><td>336</td><td>3.95</td><td>3.98</td><td>2.47</td></tr><tr><td>8</td><td>0.26</td><td>Very Good</td><td>H</td><td>SI1</td><td>61.9</td><td>55.0</td><td>337</td><td>4.07</td><td>4.11</td><td>2.53</td></tr><tr><td>9</td><td>0.22</td><td>Fair</td><td>E</td><td>VS2</td><td>65.1</td><td>61.0</td><td>337</td><td>3.87</td><td>3.78</td><td>2.49</td></tr><tr><td>10</td><td>0.23</td><td>Very Good</td><td>H</td><td>VS1</td><td>59.4</td><td>61.0</td><td>338</td><td>4.0</td><td>4.05</td><td>2.39</td></tr></tbody></table></div>

# %%
# printschema() affiche l'ensemble des variables du dataframe et leurs types
diamonds.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- carat: double (nullable = true)
# -- cut: string (nullable = true)
# -- color: string (nullable = true)
# -- clarity: string (nullable = true)
# -- depth: double (nullable = true)
# -- table: double (nullable = true)
# -- price: integer (nullable = true)
# -- x: double (nullable = true)
# -- y: double (nullable = true)
# -- z: double (nullable = true)
#
# </div>

# %% [markdown]
# ### Quelques manipulations de bases de données
# L'API dataframes de Spark offre un grand nombre de fonctions natives qui permettent de mettre en oeuvre la pluspart des traitements que l'on a l'habitude de faire avec `pandas`. Vous pouvez notamment trouver un inventaire de ces fonctions dans [cet article](https://hackersandslackers.com/transforming-pyspark-dataframes/). En vous aidant de cette syntaxe, faites le traitement suivant :
# - Dans la table `diamonds`, créez une nouvelle variable `categ_price`, égale à :
#   - "low" si le prix du diamant est inférieur à 1000$,
#   - "medium" si le prix du diamant est inférieur à 3000$,
#   - "high" si le prix du diamant est inférieur à 8000$,
#   - "very high" si le prix est au delà.
#  _Indications_ : Vous aurez besoin pour cette question des fonctions `withColumn()`, `when()`, `col()`, et `lit()`.

# %%
# création d'une nouvelle variable : on entre dans une syntaxe assez spécifique avec notamment
# withColumn() et lit()
# un petit exemple : 
from pyspark.sql.functions import lit
test = diamonds.withColumn('test', lit("texte"))
display(test.select("test"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>test</th></tr></thead><tbody><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>texte</td></tr><tr><td>tex ...

# %%
# Pour notre cas on fait quelque chose de plus complexe
from pyspark.sql.functions import lit, when, col
diamonds = diamonds.withColumn('categ_price', when(col("price") <= 1000, lit("0. low")).when(col("price") <= 3000, lit("1. medium")).when(col("price") <= 8000, lit("2. high")).otherwise(lit("3. very high")))
display(diamonds.select("price", "categ_price"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>price</th><th>categ_price</th></tr></thead><tbody><tr><td>326</td><td>0. low</td></tr><tr><td>326</td><td>0. low</td></tr><tr><td>327</td><td>0. low</td></tr><tr><td>334</td><td>0. low</td></tr><tr><td>335</td><td>0. low</td></tr><tr><td>336</td><td>0. low</td></tr><tr><td>336</td><td>0. low</td></tr><tr><td>337</td><td>0. low</td></tr><tr><td>337</td><td>0. low</td></tr><tr><td>338</td><td>0. low</td></tr><tr><td>339</td><td>0. low</td></tr><tr><td>340
r><tr><td>554</td><td>0. low</td></tr><tr><td>2757</td><td>1. medium</td></tr><tr><td>2757</td><td>1. medium</td></tr><tr><td>2757</td><td>1. medium</td></tr><tr><td>2759</td><td>1. medium</td></tr><tr><td>2759</td><td>1. medium</td></tr><tr><td>2759</td><td>1. medium</td></tr><tr><td>2759</td><td>1. medium</td></tr><tr><td>2759</td><td>1. medium</td></tr><tr><td>2760</td><td>1. medium</td></tr><tr><td>2760</td><td>1. medium</td></tr><tr><td>2760</td><td>1. medium</td></tr><tr><td>2760</td><td>1. medium</td></tr><tr><td>2760</td><td>1. medium</td></tr><tr><td>2760</td><td>1. medium</td></tr><tr><td>2760</td><td>1. medium< ...

# %%
# On peut vérifier aussi en repassant par pandas : 
import pandas as pd
pandas_diamonds = diamonds.toPandas()
print(pandas_diamonds.loc[pandas_diamonds.price >= 8000, ["price", "categ_price"]])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">       price   categ_price
# 19274   8000       2. high
# 19275   8001  3. very high
# 19276   8001  3. very high
# 19277   8001  3. very high
# 19278   8001  3. very high
# 19279   8002  3. very high
# 19280   8003  3. very high
# 19281   8004  3. very high
# 19282   8005  3. very high
# 19283   8005  3. very high
# 19284   8006  3. very high
# 19285   8008  3. very high
# 19286   8008  3. very high
# 19287   8008  3. very high
# 19288   8010  3. very high
# 19289   8010  3. very high
# 19290   8011  3. very high
# 19291   8011  3. very high
# 19292   8011  3. very high
# 19293   8012  3. very high
# 19294   8013  3. very high
# 19295   8014  3. very high
# 19296   8014  3. very high
# 19297   8014  3. very high
# 19298   8014  3. very high
# 19299   8015  3. very high
# 19300   8016  3. very high
# 19301   8017  3. very high
# 19302   8018  3. very high
# 19303   8019  3. very high
# ...      ...           ...
# 27720  18731  3. very high
# 27721  18735  3. very high
# 27722  18736  3. very high
# 27723  18741  3. very high
# 27724  18741  3. very high
# 27725  18741  3. very high
# 27726  18745  3. very high
# 27727  18756  3. very high
# 27728  18757  3. very high
# 27729  18759  3. very high
# 27730  18760  3. very high
# 27731  18766  3. very high
# 27732  18768  3. very high
# 27733  18777  3. very high
# 27734  18779  3. very high
# 27735  18780  3. very high
# 27736  18781  3. very high
# 27737  18784  3. very high
# 27738  18787  3. very high
# 27739  18788  3. very high
# 27740  18791  3. very high
# 27741  18791  3. very high
# 27742  18795  3. very high
# 27743  18795  3. very high
# 27744  18797  3. very high
# 27745  18803  3. very high
# 27746  18804  3. very high
# 27747  18806  3. very high
# 27748  18818  3. very high
# 27749  18823  3. very high
#
# [7606 rows x 2 columns]
# </div>

# %% [markdown]
# ### SQL
# Databricks vous offre aussi la possibilité de coder directement en SQL.
# - Refaites l'import des données (dans une table `diamonds_sql`) et la création de `categ_price` en utilisant le langage SQL.

# %% [markdown]
# On utilise `%sql` our coder directement en SQL :

# %%
# %sql
/* On affiche les 10 premières lignes après avoir importé la table */
DROP TABLE IF EXISTS diamonds_sql; 

CREATE TABLE diamonds_sql
USING csv
OPTIONS (path "/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv", header "true", inferSchema "true");

SELECT * from diamonds_sql
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th
td>3.84</td><td>2.33</td><td>low</td></tr><tr><td>14</td><td>0.31</td><td>Ideal</td><td>J</td><td>SI2</td><td>62.2</td><td>54.0</td><td>344</td><td>4.35</td><td>4.37</td><td>2.71</td><td>low</td></tr><tr><td>15</td><td>0.2</td><td>Premium</td><td>E</td><td>SI2</td><td>60.2</td><td>62.0</td><td>345</td><td>3.79</td><td>3.75</td><td>2.27</td><td>low</td></tr><tr><td>16</td><td>0.32</td><td>Premium</td><td>E</td><td>I1</td><td>60.9</td><td>58.0</td><td>345</td><td>4.38</td><td>4.42</td><td>2.68</td><td>low</td></tr><tr><td>17</td><td>0.3</td><td>Ideal</td><td>I</td><td>SI2</td><td>62.0</td><td>54.0</td><td>348</td><td>4.31</td><td>4.34</td><td>2.68</td><td>low</td></tr><tr><td>18</td><td>0.3</td><td>Good</td><td>J</td><td>SI1</td><td>63.4</td><td>54.0</td><td>351</td><td>4.23</td><td>4.29</td><td>2.7</td><td>low</td></tr><tr><td>19</td><td>0.3</td><td>Good</td><td>J</td><td>SI1</td><td>63.8</td><td>56.0</td><td>351</td><td>4.23</td><td>4.26</td><td>2.71</td><td>low</td></tr><tr><td>20</td><td>0.3</td><td>Very Good</td><td>J</td><td>SI1</td><td>62.7</td><td>59.0</td><td>351</td><td>4.21</td><td>4.27</td><td>2.66</td><td>low</td></tr><tr><td>21</td><td>0.3</td><td>Good</td><td>I</td><td>SI2</td><td>63.3</td><td>56.0</td><td>351</td><td>4.26</td><td>4.3</td><td>2.71</td><td>low</td></tr><tr><td>22</td><td>0.23</td><td>Very Good</td><td>E</td><td>VS2</td><td>63.8</td><td>55.0</td><td>352</td><td>3.85</td><td>3.92</td><td>2.48</td><td>low</td></tr><tr><td>23</td><td>0.23</td><td>Very Good</td><td>H</td><td>VS1</td><td>61.0</td><td>57.0</td><td>353</td><td>3.94</td><td>3.96</td><td>2.41</td><td>low</td></tr><tr><td>24</td><td>0.31</td><td>Very Good</td><td>J</td><td> ...

# %% [markdown]
# ## MLlib
# Un des grands avantages de Spark est sa librairie MLlib, qui permet de faire tourner un grand nombre de modèles de régressions, classifications, etc... Même si cette librairie n'est pas aussi complète que `scitkit-learn`, elle permet tout de même de rendre accessibles beaucoup de modèles pour des bases de données très volumineuses. Vous pouvez explorer les possibilités offertes par cette librairie en parcourant [sa documentation](https://spark.apache.org/docs/latest/ml-guide.html).

# %% [markdown]
# ### Régression linéaire
# Avec MLlib, la régression linéaire se fait à partir de deux variables :
# 1) une variable contenant toutes les valeurs numériques de nos variables explicatives concaténées dans un même vecteur grâce à la fonction `VectorAssembler`.
# 2) la variable que l'on souhaite expliquer (pour nous, ça sera le prix).
# Vous pouvez par exemple vous inspirer de [cet article](https://towardsdatascience.com/building-a-linear-regression-with-pyspark-and-mllib-d065c3ba246a) dans lequel l'auteure décrit bien les différentes étapes pour mener à bien sa régression.
#
# - Avant de mener votre régression, transformez vos variables caractères en indicatrices.

# %% [markdown]
# __Correction__
# On le fait "à la main" en créant les indicatrices en parcourant les valeurs des variables caractères :

# %%
diamonds.select("cut").distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---
td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>11</td><td>0.3</td><td>Good</td><td>J</td><td>SI1</td><td>64.0</td><td>55.0</td><td>339</td><td>4.25</td><td>4.28</td><td>2.73</td><td>0. low</td><td>0</td><td>0</td><td>1</td><td>0</td></tr><tr><td>12</td><td>0.23</td><td>Ideal</td><td>J</td><td>VS1</td><td>62.8</td><td>56.0</td><td>340</td><td>3.93</td><td>3.9</td><td>2.46</td><td>0. low</td><td>0</td><td>1</td><td>0</td><td>0</td></tr><tr><td>13</td><td>0.22</td><td>Premium</td><td>F</td><td>SI1</td><td>60.4</td><td>61.0</td><td>342</td><td>3.88</td><td>3.84</td><td>2.33</td><td>0. low</td><td>1</td><td>0</td><td>0</td><td>0</td></tr><tr><td>14</td><td>0.31</td><td>Ideal</td><td>J</td><td>SI2</td><td>62.2</td><td>54.0</td><td>344</td><td>4.35</td><td>4.37</td><td>2.71</td><td>0. low</td><td>0</td><td>1</td><td>0</td><td>0</td></tr><tr><td>15</td><td>0.2</td><td>Premium</td><td>E</td><td>SI2</td><td>60.2</td><td>62.0</td><td>345</td><td>3.79</td><td>3.75</td><td>2.27</td><td>0. low</td><td>1</td><td>0</td><td>0</td><td>0</td></tr><tr><td>16</td><td>0.32</td><td>Premium</td><td>E</td><td>I1</td><td>60.9</td><td>58.0</td><td>345</td><td>4.38</td><td>4.42</td><td>2.68</td><td>0. low</td><td>1</td><td>0</td><td>0</td><td>0</td></tr><tr><td>17</td><td>0.3</td><td>Ideal</td><td>I</td><td>SI2</td><td>62.0</td><td>54.0</td><td>348</td><td>4.31</td><td>4.34</td><td>2.68</td><td>0. low</td><td>0</td><td>1</td><td>0</td><td>0</td></tr><tr><td>18</td><td>0.3</td><td>Good</td><td>J</td><td>SI1</td><td>63.4</td><td>54.0</td><td>351</td><td>4.23</td><td>4.29</td><td>2.7</td><td>0. low</td><td>0</td><td>0</td><td>1</td><td>0</td></tr><tr><td>19 ...

# %%
diamonds.select("color").distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+
# color|
# +-----+
#     F|
#     E|
#     D|
#     J|
#     G|
#     I|
#     H|
# +-----+
#
# </div>

# %%
for i in ["F", "E", "D", "J", "G", "I"]:
  diamonds_num = diamonds_num.withColumn(f'color_{i}', when(col("color") == i, lit(1)).otherwise(lit(0)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
diamonds_num.select("clarity").distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+
# clarity|
# +-------+
#    VVS2|
#     SI1|
#      IF|
#      I1|
#    VVS1|
#     VS2|
#     SI2|
#     VS1|
# +-------+
#
# </div>

# %%
for i in ["VVS2", "SI1", "IF", "I1", "VVS1", "VS2", "SI2"]:
  diamonds_num = diamonds_num.withColumn(f'clarity_{i}', when(col("clarity") == i, lit(1)).otherwise(lit(0)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(diamonds_num)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>carat</th><th>cut</th><th>color</th><th>clarity</th><th>depth</th><th>table</th><th>price</th><th>x</th><th>y</th><th>z</th><th>categ_price</th><th>cut_Premium</th><th>cut_Ideal</th><th>cut_Good</th><th>cut_Fair</th><th>color_F</th><th>color_E</th><th>color_D</th><th>color_J</th><th>color_G</th><th>color_I</th><th>clarity_VVS2</th><th>clarity_SI1</th><th>clarity_IF</th><th>clarity_I1</th><th>clarity_VVS1</th><th>clarity_VS2</th><th>clarity_SI2</th></tr></thead><tbody><tr><td>1</td><td>0.23</td><td>Ideal</td><td>E</td><td>SI2</td><td>61.5</td><td>55.0</td><td>326</td><td>3.95</td><td>3.98</td><td>2.43</td><td>0. low</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</
# </div>

# %%
# On crée notre dataframe avec les features et le y 
# on regroupe toutes les variables numériques avec VectorAssembler
from pyspark.ml.feature import VectorAssembler
name_num = diamonds_num.drop("_c0", "color", "clarity", "cut", "price", "categ_price").columns
vectorAssembler = VectorAssembler(inputCols = name_num, outputCol = 'features')

diamonds_reg = vectorAssembler.transform(diamonds_num)
diamonds_reg.select(['features', 'price']).show(20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#             features|price|
# +--------------------+-----+
# (23,[0,1,2,3,4,5,...|  326|
# (23,[0,1,2,3,4,5,...|  326|
# (23,[0,1,2,3,4,5,...|  327|
# (23,[0,1,2,3,4,5,...|  334|
# (23,[0,1,2,3,4,5,...|  335|
# (23,[0,1,2,3,4,5,...|  336|
# (23,[0,1,2,3,4,5,...|  336|
# (23,[0,1,2,3,4,5,...|  337|
# (23,[0,1,2,3,4,5,...|  337|
# (23,[0,1,2,3,4,5]...|  338|
# (23,[0,1,2,3,4,5,...|  339|
# (23,[0,1,2,3,4,5,...|  340|
# (23,[0,1,2,3,4,5,...|  342|
# (23,[0,1,2,3,4,5,...|  344|
# (23,[0,1,2,3,4,5,...|  345|
# (23,[0,1,2,3,4,5,...|  345|
# (23,[0,1,2,3,4,5,...|  348|
# (23,[0,1,2,3,4,5,...|  351|
# (23,[0,1,2,3,4,5,...|  351|
# (23,[0,1,2,3,4,5,...|  351|
# +--------------------+-----+
# only showing top 20 rows
#
# </div>

# %%
# On fait tourner le modèle de régression linéaire et on sort les coefficients
from pyspark.ml.regression import LinearRegression
lr = LinearRegression(featuresCol = 'features', labelCol='price', maxIter=100)
lr_model = lr.fit(diamonds_reg)
coeff = {}
for i in range(len(name_num)):
  coeff[name_num[i]] = lr_model.coefficients[i]
print(coeff)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;carat&#39;: 11256.978307514004, &#39;depth&#39;: -63.80610034421339, &#39;table&#39;: -26.474084661428268, &#39;x&#39;: -1008.2610980555075, &#39;y&#39;: 9.608886459633506, &#39;z&#39;: -50.11889112919464, &#39;cut_Premium&#39;: 35.36135898441713, &#39;cut_Ideal&#39;: 106.12925333635954, &#39;cut_Good&#39;: -147.0311459245811, &#39;cut_Fair&#39;: -726.7825914909496, &#39;color_F&#39;: 707.4128434210736, &#39;color_E&#39;: 771.1485901239862, &#39;color_D&#39;: 980.2666753940987, &#39;color_J&#39;: -1389.131387507999, &#39;color_G&#39;: 498.22777157581277, &#39;color_I&#39;: -485.97779868132096, &#39;clarity_VVS2&#39;: 372.4161564412181, &#39;clarity_SI1&#39;: -912.9258354358905, &#39;clarity_IF&#39;: 766.7043305605101, &#39;clarity_I1&#39;: -4578.397915233039, &#39;clarity_VVS1&#39;: 429.36112971415685, &#39;clarity_VS2&#39;: -311.1743499180288, &#39;clarity_SI2&#39;: -1875.8116211430315}
# </div>

# %%
print(lr_model.coefficients)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[11256.978307514004,-63.80610034421339,-26.474084661428268,-1008.2610980555075,9.608886459633506,-50.11889112919464,35.36135898441713,106.12925333635954,-147.0311459245811,-726.7825914909496,707.4128434210736,771.1485901239862,980.2666753940987,-1389.131387507999,498.22777157581277,-485.97779868132096,372.4161564412181,-912.9258354358905,766.7043305605101,-4578.397915233039,429.36112971415685,-311.1743499180288,-1875.8116211430315]
# </div>

# %%
# on sort le R2
lr_summary = lr_model.summary
print(lr_summary.r2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.9197914950935602
# </div>

# %%
# on sort les p-values : 
lr_summary.pValues
p_val = {}
for i in range(len(name_num)):
  p_val[name_num[i]] = str(lr_summary.pValues[i])
print(p_val)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;carat&#39;: &#39;0.0&#39;, &#39;depth&#39;: &#39;0.0&#39;, &#39;table&#39;: &#39;0.0&#39;, &#39;x&#39;: &#39;0.0&#39;, &#39;y&#39;: &#39;0.6191751404698669&#39;, &#39;z&#39;: &#39;0.13447762694593868&#39;, &#39;cut_Premium&#39;: &#39;0.014098944029433236&#39;, &#39;cut_Ideal&#39;: &#39;8.815170815523743e-14&#39;, &#39;cut_Good&#39;: &#39;4.884981308350689e-14&#39;, &#39;cut_Fair&#39;: &#39;0.0&#39;, &#39;color_F&#39;: &#39;0.0&#39;, &#39;color_E&#39;: &#39;0.0&#39;, &#39;color_D&#39;: &#39;0.0&#39;, &#39;color_J&#39;: &#39;0.0&#39;, &#39;color_G&#39;: &#39;0.0&#39;, &#39;color_I&#39;: &#39;0.0&#39;, &#39;clarity_VVS2&#39;: &#39;0.0&#39;, &#39;clarity_SI1&#39;: &#39;0.0&#39;, &#39;clarity_IF&#39;: &#39;0.0&#39;, &#39;clarity_I1&#39;: &#39;0.0&#39;, &#39;clarity_VVS1&#39;: &#39;0.0&#39;, &#39;clarity_VS2&#39;: &#39;0.0&#39;, &#39;clarity_SI2&#39;: &#39;0.0&#39;}
# </div>

# %% [markdown]
# On déduit des p-values qu'on peut sortir y et z

# %%
name_num = diamonds_num.drop("_c0", "color", "clarity", "cut", "price", "categ_price", "y", "z").columns
vectorAssembler = VectorAssembler(inputCols = name_num, outputCol = 'features')
diamonds_reg = vectorAssembler.transform(diamonds_num)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# On fait maintenant un modèle de prédiction
splits = diamonds_reg.randomSplit([0.7, 0.3])
train_diamonds = splits[0]
test_diamonds = splits[1]

lr_train_test = lr.fit(train_diamonds)
print(lr_train_test.summary.r2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.9216171448702871
# </div>

# %%
# on applique la prédiction
lr_predictions = lr_train_test.transform(test_diamonds)
display(lr_predictions)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>carat</th><th>cut</th><th>color</th><th>clarity</th><th>depth</th><th>table</th><th>price</th><th>x</th><th>y</th><th>z</th><th>categ_price</th><th>cut_Premium</th><th>cut_Ideal</th><th>cut_Good</th><th>cut_Fair</th><th>color_F</th><th>color_E</th><th>color_D</th><th>color_J</th><th>color_G</th><th>color_I</th><th>clarity_VVS2</th><th>clarity_SI1</th><th>clarity_IF</th><th>clarity_I1</th><th>clarity_VVS1</th><th>clarity_VS2</th><th>clarity_SI2</th><th>features</th><th>prediction</th></tr></thead><tbody><tr><td>3</td><td>0.23</td><td>Good</td><td>E</td><td>VS1</td><td>56.9</td><td>65.0</td><td>327</td><td>4.05</td><td>4.07</td><td>2.31</td><td>0. low</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>List(0, 21, List(0, 1, 2, 3, 6, 9), List(0.23, 56.9, 65.0, 4.05, 1.0, 1.0))</td><td>241.53905074893737</td></tr><tr><td>6</td><td>0.24</td><td>Very Good</td><td>J</td><td>VVS2</td><td>62.8</td><td>57.0</td><td>336</td><td>3.94</td><td>3.96</td><td>2.48</td><td>0. low</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>List(0, 21, List(0, 1, 2, 3, 11, 14), List(0.24, 62.8, 57.0, 3.94, 1.0, 1.0))</td><td>-1346.1564247656752</td></tr><tr><td>9</td><td>0.22</td><td>Fair</td><td>E</td><td>VS2</td><td>65.1</td><td>61.0</td><td>337</td><td>3.87</td><td>3.78</td><td>2.49</td><td>0. low</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>List(0, 21, List(0, 1, 2, 3, 7, 9, 19), List(0.22, 65.1, 61.0, 3.87, 1.0, 1.0, 1.0))</td><td>-1024.614101734277</td></tr><tr><td>14</td><td>0.31</td><td>Ideal</td><td>J</td><td>SI2</td><td>62.2</td><td>54.0</td><td>344</td><td>4.35</td><td>4.37</td><td>2.71</td><td>0. low</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>List(0, 21, List(0, 1, 2, 3, 5, 11, 20), List(0.31, 62.2, 54.0, 4.35, 1.0, 1.0, 1.0))</td><td>-3008.791628204156</td></tr><tr><td>29</td><td>0.23</td><td>Very Good</td><td>D</td><td>VS2</td><td>60.5</td><td>61.0</td><td>357</td><td>3.96</td><td>3.97</td><td>2.4</td><td>0. low</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>List(0, 21, List(0, 1, 2, 3, 10, 19), List(0.23, 60.5, 61.0, 3.96, 1.0, 1.0))</td><td>258.84651318203396</td></tr><tr><td>31</td><td>0.23</td><td>Very Good</td><td>F</td><td>VS1</td><td>60.0</td><td>57.0</td><td>402</td><td>4.0</td><td>4.03</td><td>2.41</td><td>0. low</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>List(0, 21, List(0, 1, 2, 3, 8), List(0.23, 60.0, 57.0, 4.0, 1.0))</td><td>369.56907126033093</td></tr><tr><td>35</td><td>0.23</td><td>Very Good</td><td>D</td><td>VS1</td><td>61.9</td><td>58.0</td><td>402</td><td>3.92</td><td>3.96</td><td>2.44</td><td>0. low</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>List(0, 21, List(0, 1, 2, 3, 10), List(0.23, 61.9, 58.0, 3.92, 1.0))</td><td>579.3803658255674</td></tr><tr><td>37</td><td>0.23</td><td>Good</td><td>E</td><td>VS1</td><td>64.1</td><td>59.0</td><td>402</td><td>3.83</td><td>3.85</td><td>2.46</td><td>0. low</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0 ...

# %%
# on sort MAE et rmse pour juger de la qualité de la prédiction
test_result = lr_train_test.evaluate(test_diamonds)
# RMSE
print(test_result.rootMeanSquaredError)
# MAE
print(test_result.meanAbsoluteError)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1147.3261800675634
# 740.4669288129359
# </div>

# %% [markdown]
# ### Classification
# - Entraînez un modèle randomforest qui permettent de classer le diamant en `categ_price` en fonction de ses caractéristiques. Proposez des indicateurs pour évaluer la qualité prédictive de votre modèle.
#
# __Indications__
# Pour utiliser les variables catégorielles pour la classification, transformez les en index avec `StringIndexer`. Vous devrez aussi utiliser cette fonction pour votre variable expliquée! Vous pouvez ensuite créez votre colonne "features" mais au sein de celle-ci vous devrez ensuite appliquer un VectorAssembler pour indiquer quels sont les variables catégorielles (fixez bien le paramètre `maxCategories` à cet effet).
