# %% [markdown]
# Exemple de la [documentation](https://spark.apache.org/docs/latest/ml-features#onehotencoderestimator)

# %%
df = spark.createDataFrame([
    ("couleur 1", "forme 3"),
    ("couleur 2", "forme 1"),
    ("couleur 1", "forme 1"),
    ("couleur 3", "forme 2"),
    ("couleur 1", "forme 1"),
    ("couleur 2", "forme 3")
], ["categorycarac1", "categorycarac2"])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>categorycarac1</th><th>categorycarac2</th></tr></thead><tbody><tr><td>couleur 1</td><td>forme 3</td></tr><tr><td>couleur 2</td><td>forme 1</td></tr><tr><td>couleur 1</td><td>forme 1</td></tr><tr><td>couleur 3</td><td>forme 2</td></tr><tr><td>couleur 1</td><td>forme 1</td></tr><tr><td>couleur 2</td><td>forme 3</td></tr></tbody></table></div>

# %%
from pyspark.ml.feature import StringIndexer

# On passe les caractères en numériques avec StringIndexer
indexer = StringIndexer(inputCol="categorycarac1", outputCol="categoryIndex1").fit(df)
df = indexer.transform(df)
indexer = StringIndexer(inputCol="categorycarac2", outputCol="categoryIndex2").fit(df)
df = indexer.transform(df)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>categorycarac1</th><th>categorycarac2</th><th>categoryIndex1</th><th>categoryIndex2</th></tr></thead><tbody><tr><td>couleur 1</td><td>forme 3</td><td>0.0</td><td>1.0</td></tr><tr><td>couleur 2</td><td>forme 1</td><td>1.0</td><td>0.0</td></tr><tr><td>couleur 1</td><td>forme 1</td><td>0.0</td><td>0.0</td></tr><tr><td>couleur 3</td><td>forme 2</td><td>2.0</td><td>2.0</td></tr><tr><td>couleur 1</td><td>forme 1</td><td>0.0</td><td>0.0</td></tr><tr><td>couleur 2</td><td>forme 3</td><td>1.0</td><td>1.0</td></tr></tbody></table></div>

# %%
# On passe chaque vecteur numérique en vecteur de booléens
# le OneHotEncoder estimator crée n-1 valeurs binaires regroupées dans un même vecteur
# avec n = nombre de valeurs du vecteur
from pyspark.ml.feature import OneHotEncoderEstimator
encoder = OneHotEncoderEstimator(inputCols=["categoryIndex1", "categoryIndex2"],
                                 outputCols=["categoryVec1", "categoryVec2"])
model = encoder.fit(df)
encoded = model.transform(df)
encoded.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+--------------+--------------+--------------+-------------+-------------+
# categorycarac1|categorycarac2|categoryIndex1|categoryIndex2| categoryVec1| categoryVec2|
# +--------------+--------------+--------------+--------------+-------------+-------------+
#      couleur 1|       forme 3|           0.0|           1.0|(2,[0],[1.0])|(2,[1],[1.0])|
#      couleur 2|       forme 1|           1.0|           0.0|(2,[1],[1.0])|(2,[0],[1.0])|
#      couleur 1|       forme 1|           0.0|           0.0|(2,[0],[1.0])|(2,[0],[1.0])|
#      couleur 3|       forme 2|           2.0|           2.0|    (2,[],[])|    (2,[],[])|
#      couleur 1|       forme 1|           0.0|           0.0|(2,[0],[1.0])|(2,[0],[1.0])|
#      couleur 2|       forme 3|           1.0|           1.0|(2,[1],[1.0])|(2,[1],[1.0])|
# +--------------+--------------+--------------+--------------+-------------+-------------+
#
# </div>

# %%
print(encoded.select("categoryVec1").collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Row(categoryVec1=SparseVector(2, {0: 1.0})), Row(categoryVec1=SparseVector(2, {1: 1.0})), Row(categoryVec1=SparseVector(2, {0: 1.0})), Row(categoryVec1=SparseVector(2, {})), Row(categoryVec1=SparseVector(2, {0: 1.0})), Row(categoryVec1=SparseVector(2, {1: 1.0}))]
# </div>

# %%
# on peut faire un VectorAssembler sur tout ce beau monde 
# note : aucun problème pour faire un vectorAssembler avec des 
# colonnes vecteurs et non vecteurs
from pyspark.ml.feature import VectorAssembler
assembler = VectorAssembler(inputCols=["categoryVec1", "categoryVec2"],outputCol="features")
encoded_2 =  assembler.transform(encoded)
encoded_2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+--------------+--------------+--------------+-------------+-------------+-----------------+
# categorycarac1|categorycarac2|categoryIndex1|categoryIndex2| categoryVec1| categoryVec2|         features|
# +--------------+--------------+--------------+--------------+-------------+-------------+-----------------+
#      couleur 1|       forme 3|           0.0|           1.0|(2,[0],[1.0])|(2,[1],[1.0])|[1.0,0.0,0.0,1.0]|
#      couleur 2|       forme 1|           1.0|           0.0|(2,[1],[1.0])|(2,[0],[1.0])|[0.0,1.0,1.0,0.0]|
#      couleur 1|       forme 1|           0.0|           0.0|(2,[0],[1.0])|(2,[0],[1.0])|[1.0,0.0,1.0,0.0]|
#      couleur 3|       forme 2|           2.0|           2.0|    (2,[],[])|    (2,[],[])|        (4,[],[])|
#      couleur 1|       forme 1|           0.0|           0.0|(2,[0],[1.0])|(2,[0],[1.0])|[1.0,0.0,1.0,0.0]|
#      couleur 2|       forme 3|           1.0|           1.0|(2,[1],[1.0])|(2,[1],[1.0])|[0.0,1.0,0.0,1.0]|
# +--------------+--------------+--------------+--------------+-------------+-------------+-----------------+
#
# </div>
