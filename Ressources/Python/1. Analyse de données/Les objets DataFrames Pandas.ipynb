# %% [markdown]
# # Les objets DataFrames Pandas

# %% [markdown]
# Importer les données 'fandango_score_comparison'

# %%
import pandas as pd

fandango = pd.read_csv('Data/fandango-score-comparison.csv')
fandango.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %% [markdown]
# ## Indexage avec des entiers

# %%
fandango[142:]
# Out:
#                                           FILM  RottenTomatoes  \
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 142                   82          83              7.5   7.2             3.5
# 143                   78          89              8.8   7.4             3.5
# 144                   81          90              7.3   7.8             3.5
# 145                   63          68              6.4   6.7             3.5
#
#      Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  IMDB_norm  \
# 142                   3.5     4.85          4.10  ...       3.60
# 143                   3.5     4.85          3.90  ...       3.70
# 144                   3.5     5.00          4.05  ...       3.90
# ...

# %%
fandango[-4:-1]
# Out:
#                                           FILM  RottenTomatoes  \
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 142                   82          83              7.5   7.2             3.5
# 143                   78          89              8.8   7.4             3.5
# 144                   81          90              7.3   7.8             3.5
#
#      Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  IMDB_norm  \
# 142                   3.5     4.85          4.10  ...        3.6
# 143                   3.5     4.85          3.90  ...        3.7
# 144                   3.5     5.00          4.05  ...        3.9
#
#      RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 142            5.0                 4.0                    4.0
# ...

# %%
fandango.iloc[2]
# Out:
# FILM                          Ant-Man (2015)
# RottenTomatoes                            80
# RottenTomatoes_User                       90
# Metacritic                                64
# Metacritic_User                          8.1
# IMDB                                     7.8
# Fandango_Stars                             5
# Fandango_Ratingvalue                     4.5
# RT_norm                                    4
# RT_user_norm                             4.5
# Metacritic_norm                          3.2
# Metacritic_user_nom                     4.05
# IMDB_norm                                3.9
# RT_norm_round                              4
# RT_user_norm_round                       4.5
# Metacritic_norm_round                      3
# Metacritic_user_norm_round                 4
# IMDB_norm_round                            4
# Metacritic_user_vote_count               627
# IMDB_user_vote_count                  103660
# Fandango_votes                         12055
# ...

# %%
fandango.iloc[[2,142,42]]
# Out:
#                   FILM  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 2       Ant-Man (2015)              80                   90          64
# 142         '71 (2015)              97                   82          83
# 42   About Elly (2015)              97                   86          87
#
#      Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 2                8.1   7.8             5.0                   4.5     4.00
# 142              7.5   7.2             3.5                   3.5     4.85
# 42               9.6   8.2             4.0                   3.6     4.85
#
#      RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 2             4.5  ...        3.9            4.0                 4.5
# 142           4.1  ...        3.6            5.0                 4.0
# 42            4.3  ...        4.1            5.0                 4.5
#
#      Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# ...

# %% [markdown]
# Retourner un DataFrame contenant seulement la première et la dernière ligne

# %%
first_last = fandango.iloc[[0,fandango.shape[0]-1]]
first_last
# Out:
#                                    FILM  RottenTomatoes  RottenTomatoes_User  \
# 0        Avengers: Age of Ultron (2015)              74                   86
# 145  Kumiko, The Treasure Hunter (2015)              87                   63
#
#      Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0            66              7.1   7.8             5.0                   4.5
# 145          68              6.4   6.7             3.5                   3.5
#
#      RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 0       3.70          4.30  ...       3.90            3.5                 4.5
# 145     4.35          3.15  ...       3.35            4.5                 3.0
#
#      Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 0                      3.5                         3.5              4.0
# 145                    3.5                         3.0              3.5
#
# ...

# %% [markdown]
# ## Indexage personnalisé

# %% [markdown]
# - Créer un nouveau dataframe fandango_perso avec la colonne 'FILM' comme index en utilisant la méthode set_index (remarque : on veut conserver la colonne 'FILM')
# - Afficher les indexes du DataFrame fandango_perso

# %%
fandango_perso = fandango.set_index('FILM', drop=False)
#print(fandango_perso.index)
fandango_perso
# Out:
#                                                                                           FILM  \
# FILM
# Avengers: Age of Ultron (2015)                                  Avengers: Age of Ultron (2015)
# Cinderella (2015)                                                            Cinderella (2015)
# Ant-Man (2015)                                                                  Ant-Man (2015)
# Do You Believe? (2015)                                                  Do You Believe? (2015)
# Hot Tub Time Machine 2 (2015)                                    Hot Tub Time Machine 2 (2015)
# The Water Diviner (2015)                                              The Water Diviner (2015)
# Irrational Man (2015)                                                    Irrational Man (2015)
# Top Five (2014)                                                                Top Five (2014)
# Shaun the Sheep Movie (2015)                                      Shaun the Sheep Movie (2015)
# ...

# %% [markdown]
# ## Sélectionner des valeurs depuis un index (personnalisé ou non)

# %% [markdown]
# Créer un dataframe films contenant les films suivants dans l'ordre indiqué :
# - "Top Five (2014)"
# - "Black Sea (2015)"
# - "Taken 3 (2015)"
#
# Le faire de 2 manières : l'une utilisera le dataframe fandango initial et l'autre utilisera le dataframe fandango_perso

# %%
films = fandango[[f in ["Top Five (2014)","Black Sea (2015)","Taken 3 (2015)"] for f in fandango['FILM']]]
films
# Out:
#                 FILM  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 7    Top Five (2014)              86                   64          81
# 11  Black Sea (2015)              82                   60          62
# 15    Taken 3 (2015)               9                   46          26
#
#     Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 7               6.8   6.5             4.0                   3.5     4.30
# 11              6.6   6.4             4.0                   3.5     4.10
# 15              4.6   6.1             4.5                   4.1     0.45
#
#     RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 7            3.2  ...       3.25            4.5                 3.0
# 11           3.0  ...       3.20            4.0                 3.0
# 15           2.3  ...       3.05            0.5                 2.5
#
#     Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# ...

# %%
films = fandango_perso.loc[["Top Five (2014)","Black Sea (2015)","Taken 3 (2015)"]]
films
# Out:
#                               FILM  RottenTomatoes  RottenTomatoes_User  \
# FILM
# Top Five (2014)    Top Five (2014)              86                   64
# Black Sea (2015)  Black Sea (2015)              82                   60
# Taken 3 (2015)      Taken 3 (2015)               9                   46
#
#                   Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# FILM
# Top Five (2014)           81              6.8   6.5             4.0
# Black Sea (2015)          62              6.6   6.4             4.0
# Taken 3 (2015)            26              4.6   6.1             4.5
#
#                   Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  IMDB_norm  \
# FILM                                                           ...
# Top Five (2014)                    3.5     4.30           3.2  ...       3.25
# Black Sea (2015)                   3.5     4.10           3.0  ...       3.20
# Taken 3 (2015)                     4.1     0.45           2.3  ...       3.05
#
# ...

# %% [markdown]
# ## Méthode Apply() sur les colonnes d'un DataFrame

# %% [markdown]
# - Obtenir le dataframe float_df qui ne contient que les colonnes de type décimales float64
# >- dtypes est votre ami
# >- vaut-il mieux utiliser le dataframe fandango ou bien fandango_perso (indexés par les films) ?
# - Diviser par 2 chaque valeur, élever chaque valeur au carré, calculer la déviation standard de chaque colonne
# >- apply et la fonction std de la limbraire numpy sont vos amis
# >- stocker les résultats dans 2 variables

# %%
filtre_float= fandango.dtypes == 'float64'
filtre_float.values
float_df = fandango[filtre_float.index[filtre_float]]

# %%
#div2 = float_df.apply(lambda x : x/2)
#div2.head(3)
def div(x):
    return x/2

div2 = float_df.apply(div)
div2.head(3)
# Out:
#    Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 0             3.55  3.90             2.5                  2.25    1.850
# 1             3.75  3.55             2.5                  2.25    2.125
# 2             4.05  3.90             2.5                  2.25    2.000
#
#    RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 0          2.15            1.650                1.775      1.950
# 1          2.00            1.675                1.875      1.775
# 2          2.25            1.600                2.025      1.950
#
#    RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 0           1.75                2.25                   1.75
# 1           2.25                2.00                   1.75
# 2           2.00                2.25                   1.50
#
#    Metacritic_user_norm_round  IMDB_norm_round  Fandango_Difference
# 0                        1.75             2.00                 0.25
# ...

# %%
exp2 = float_df.apply(lambda x : x**2)
exp2.head(3)
# Out:
#    Metacritic_User   IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 0            50.41  60.84            25.0                 20.25  13.6900
# 1            56.25  50.41            25.0                 20.25  18.0625
# 2            65.61  60.84            25.0                 20.25  16.0000
#
#    RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 0         18.49          10.8900              12.6025    15.2100
# 1         16.00          11.2225              14.0625    12.6025
# 2         20.25          10.2400              16.4025    15.2100
#
#    RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 0          12.25               20.25                  12.25
# 1          20.25               16.00                  12.25
# 2          16.00               20.25                   9.00
#
#    Metacritic_user_norm_round  IMDB_norm_round  Fandango_Difference
# 0                       12.25            16.00                 0.25
# ...

# %%
import numpy as np
std = float_df.apply(np.std)
std
# Out:
# Metacritic_User               1.505529
# IMDB                          0.955447
# Fandango_Stars                0.538532
# Fandango_Ratingvalue          0.501106
# RT_norm                       1.503265
# RT_user_norm                  0.997787
# Metacritic_norm               0.972522
# Metacritic_user_nom           0.752765
# IMDB_norm                     0.477723
# RT_norm_round                 1.509404
# RT_user_norm_round            1.003559
# Metacritic_norm_round         0.987561
# Metacritic_user_norm_round    0.785412
# IMDB_norm_round               0.501043
# Fandango_Difference           0.152141
# dtype: float64

# %% [markdown]
# ## Méthode Apply() sur les lignes d'un DataFrame

# %% [markdown]
# - Utiliser la méthode apply() pour calculer la moyenne (méthode mean() de la librairie Numpy) des valeurs de chaque film pour 'RT_user_norm' et 'metacritic_user_nom' puis assigner le résultat à la variable rt_mc_means
# - Afficher les 7 premières valeurs de rt_mt_means

# %%
rt_mc_means = float_df[['RT_user_norm', 'Metacritic_user_nom']].apply(np.mean, axis=1)
rt_mc_means[0:7]
# Out:
# 0    3.925
# 1    3.875
# 2    4.275
# 3    3.275
# 4    1.550
# 5    3.250
# 6    3.225
# dtype: float64
