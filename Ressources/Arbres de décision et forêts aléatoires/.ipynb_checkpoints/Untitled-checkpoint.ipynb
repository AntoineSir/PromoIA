# %% [markdown]
# # Classification à partir d'un arbre de décision et de forêts aléatoires

# %% [markdown]
# On va utiliser le jeu de données Pima Indian Diabetes disponible [là par exemple](https://www.kaggle.com/uciml/pima-indians-diabetes-database). Le dataset est déjà chargé dans l'environnement.

# %% [markdown]
# ## Import des librairies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import des données

# %%
data = pd.read_csv("diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Visualisation, analyse exploratoire et gestion des éventuels problèmes sur les données

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True);

# %%
data.hist(bins=50, figsize=(12, 9));

# %%
# problème avec les 0 pour les variables : BMI, BloodPressure, Glucose, SkinThickness, Insulin
from sklearn.impute import SimpleImputer
variables_with_0 = ['BMI', 'BloodPressure', 'Glucose', 'SkinThickness', 'Insulin']
median_imputer = SimpleImputer(missing_values=0, strategy='median')
data[variables_with_0] = median_imputer.fit_transform(data[variables_with_0])

# %%
data.hist(bins=50, figsize=(12, 9));

# %%
sns.pairplot(data, hue='Outcome');

# %% [markdown]
# ## Préparation des différents datasets pour la modélisation

# %%
X = data.drop("Outcome", axis=1)
y = data["Outcome"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (614, 8) (154, 8) (614,) (154,)

# %% [markdown]
# ## Un premier arbre de décision

# %% [markdown]
# Créer et entrainer un arbre de décision puis calculer l'accuracy et afficher l'arbre obtenu.

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7077922077922078

# %%
from sklearn.tree import export_graphviz
from IPython.display import Image  
import pydotplus

dot_data = export_graphviz(clf, out_file=None,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names = X.columns,
                class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data)  
graph.write_png('diabetes.png')
Image(graph.create_png())

# %% [markdown]
# ## Un second arbre de décision

# %% [markdown]
# Refaire la même chose en modifiant les paramètres de la classe `DecisionTreeClassifier`, notamment `max_depth` et `criterion`.

# %%
# Modèle
clf = DecisionTreeClassifier(criterion = 'entropy', max_depth=4)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Affichage
dot_data = export_graphviz(clf, out_file=None,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names = X.columns,
                class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data)  
graph.write_png('diabetes.png')
Image(graph.create_png())
# Out:
# Accuracy: 0.7597402597402597

# %% [markdown]
# ## Un peu de validation croisée pour affiner les hyperparamètres

# %% [markdown]
# Utiliser la fonction adéquate pour tester différentes valeurs des paramètres(`max_depth` et `criterion`).

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'max_depth': list(range(1,8)), 'criterion':["gini", "entropy"]}

grid_cv = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=30, scoring='accuracy')
grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=30, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 4, 5, 6, 7]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print("Meilleurs paramètres sur le jeu d'entraînement:")
print(grid_cv.best_params_)

# Afficher les performances correspondantes
print("Résultats de la validation croisée :")
for mean, std, params in zip(
        grid_cv.cv_results_['mean_test_score'],
        grid_cv.cv_results_['std_test_score'],
        grid_cv.cv_results_['params']
    ):

    print("'accuracy' = {:.3f} (+/-{:.03f}) for {}".format(mean,std*2,params))
# Out:
# Meilleurs paramètres sur le jeu d'entraînement:
# {'criterion': 'entropy', 'max_depth': 3}
# Résultats de la validation croisée :
# 'accuracy' = 0.692 (+/-0.177) for {'criterion': 'gini', 'max_depth': 1}
# 'accuracy' = 0.720 (+/-0.205) for {'criterion': 'gini', 'max_depth': 2}
# 'accuracy' = 0.722 (+/-0.199) for {'criterion': 'gini', 'max_depth': 3}
# 'accuracy' = 0.705 (+/-0.235) for {'criterion': 'gini', 'max_depth': 4}
# 'accuracy' = 0.707 (+/-0.234) for {'criterion': 'gini', 'max_depth': 5}
# 'accuracy' = 0.700 (+/-0.220) for {'criterion': 'gini', 'max_depth': 6}
# 'accuracy' = 0.704 (+/-0.264) for {'criterion': 'gini', 'max_depth': 7}
# 'accuracy' = 0.703 (+/-0.194) for {'criterion': 'entropy', 'max_depth': 1}
# 'accuracy' = 0.715 (+/-0.219) for {'criterion': 'entropy', 'max_depth': 2}
# 'accuracy' = 0.731 (+/-0.212) for {'criterion': 'entropy', 'max_depth': 3}
# 'accuracy' = 0.704 (+/-0.197) for {'criterion': 'entropy', 'max_depth': 4}
# 'accuracy' = 0.720 (+/-0.206) for {'criterion': 'entropy', 'max_depth': 5}
# 'accuracy' = 0.726 (+/-0.187) for {'criterion': 'entropy', 'max_depth': 6}
# 'accuracy' = 0.708 (+/-0.201) for {'criterion': 'entropy', 'max_depth': 7}

# %%
# autre affichage
res = pd.DataFrame(zip(grid_cv.cv_results_['mean_test_score'],
                       grid_cv.cv_results_['std_test_score'],
                       grid_cv.cv_results_['params']),
                  columns = ['mean', 'std', 'params'])

#plt.errorbar(x=list(range(7)), y=res.loc[:7,'mean'].values, yerr=res.loc[:7,'std']);
#plt.plot(res.loc[7:,'mean']);

# %%
best_tree = grid_cv.best_estimator_

# %%
y_pred = best_tree.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7597402597402597

# %% [markdown]
# ## Et une petite forêt aléatoire pour finir...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=250)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8051948051948052

# %% [markdown]
# ## ...avec validation croisée pour le nombre d'arbres de la forêt

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'n_estimators':[10, 100, 250, 500, 1000]}

grid_cv = GridSearchCV(RandomForestClassifier(), param_grid, cv=10, scoring='accuracy')
grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_estimators': [10, 100, 250, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print("Meilleurs paramètres sur le jeu d'entraînement:")
print(grid_cv.best_params_)

# Afficher les performances correspondantes
print("Résultats de la validation croisée :")
for mean, std, params in zip(
        grid_cv.cv_results_['mean_test_score'],
        grid_cv.cv_results_['std_test_score'],
        grid_cv.cv_results_['params']
    ):

    print("'accuracy' = {:.3f} (+/-{:.03f}) for {}".format(mean,std*2,params))
# Out:
# Meilleurs paramètres sur le jeu d'entraînement:
# {'n_estimators': 250}
# Résultats de la validation croisée :
# 'accuracy' = 0.752 (+/-0.119) for {'n_estimators': 10}
# 'accuracy' = 0.753 (+/-0.113) for {'n_estimators': 100}
# 'accuracy' = 0.757 (+/-0.110) for {'n_estimators': 250}
# 'accuracy' = 0.744 (+/-0.120) for {'n_estimators': 500}
# 'accuracy' = 0.743 (+/-0.128) for {'n_estimators': 1000}

# %%
best_rf = grid_cv.best_estimator_
y_pred = best_rf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7987012987012987
